# %%
## Welcome to machine and deep learning(MANY LAYERS AKA DEEP) with pytorch
##Machine learning is turning things(data) into numbers and finding patterns in those numbers.
##The data can be anything text,images etc.
##Machine learning vs Deep learning
##Dl is a subset of AI and ML
##AI>>ML>>DL
##DIFFERENCE BETWEEN ML AND TRADITIONAL PROGRAMMING
##In traditional programming we take the input and a set of rules to generate the desired output.
##In a ML algorithm we take inputs and their outputs and the machine try to comes up with a set of rules, by this set 
##of rules it tries to predict the output of a given input, basically it teaches itself without the need of explicit programming.
##The above is a supervised ML algorithm.
##I use ML and DL as same, i consider them as a same sector, however ML is a much broader sector.
##Why use ML or DL
##Can you come with a set of rules that include every condition like driving which is a very complex problem,can you
##write every line of code for this , the answer is no, thatswhy we use DL.
##LET COMPUTER GENERATES THE SET OF RULES FOR A VERY COMPLEX PROBLEM.
##yOU CAN USE ml FOR EVERYTHING AS LONG AS YOU ARE ABLE TO CONVERT THAT PROBLEM DATA INTO NUMBERS.
##LINE FROM GOOGLE MACHINE LEARNING HANDBOOK
##IF YOU CAN BUILD A SIMPLE RULE BASED SYSTEM THAT DOES NOT REQUIRE MACHINE LEARNING, DO THAT.....

# %%
##WHERE dl is good---->>>>
#1)problem with long list of rules
#2)continuously changing environment
#3)large collection of data that are different from each other
##where dl is not good
#1)when error is not acceptable as ml model output many times are wrong.
#2)when you can build a simple rule based system
#3)when you need to know the explaination as most of the timespatterns learned by a DL model is uninterpretable by the humans.
#4)less data

# %% [markdown]
#  ML                        VS                         DL
#  uses structured data                              better with unstructured data like natural language,image                                                            data,audio etc.
#  algorithms->                                      algorithms->
#  1) random forest                                  1) neural networks
#  2) gradient boosted models                        2) fully connected neural network
#  3) naive bayes                                    3) convolutional neural network
#  4) nearest neighbours                             4) recurrent neural network
#  5) support vector machine                         5) transformer(natural language)

# %%
##In this notebook we will learn first three of DL algorithms......
##we will build them with pytorch.......

# %%
##WHAT ARE NEURAL NETWORKS
the inputs are unstructured data like image,speech or natural language , these data are first converted into numbers 
in the form of tensor as nn operates on numbers, this is called number encoding. these numbers are then passed into the
nn.there is a input layer,hidden layer and a output layer.it then learns patterns or formally weights.
it then outputs the weights THAT CAN DO OUR DESIRED SOLUTION.
The hidden layers work on linear as well as non linear functions.

# %% [markdown]
# ![ASSSS.png](attachment:ASSSS.png)

# %%
## types of learning
1)supervised learning
2)unsupervised learning and self supervised learning
3)transfer learning
4)Reinforcement learning

# %%
##SUPERVISED LEARNING

# %%
##UNSUPERVISED LEARNING

# %%
##SELF SUPERVISED LEARNING

# %%
##TRANSFER LEARNING

# %%
##REINFORCEMENT LEARNING

# %%
##regression and classification

# %%
## where deep learning is used, practical examples
1)computer vision
2)recommendation
3)spam detector
4)speech recognition
5)natural language processing
6)translation

# %%
## pytorch leverages tpu (tensor processing unit) and gpu (graphics processsing unit)
->pytorch codes of ML /DL is based on a datastructure called tensors, and tensors leverages cuda that is the 
->tensors can be operated on multiple gpus, this accelerate our machine learning code and training time.
->in this course we will focus on gpus which are more popular than tpus.

# %%
## what is pytorch
->PyTorch is a machine learning framework based on the Torch library,used for applications such as computer vision and natural language processing
originally developed by Meta AI and now part of the Linux Foundation umbrella.It is free and open-source software released under the modified BSD license. 
Although the Python interface is more polished and the primary focus of development, PyTorch also has a C++ interface.[12]
A number of pieces of deep learning software are built on top of PyTorch, including Tesla Autopilot,Uber's Pyro,Hugging Face's Transformers,
PyTorch Lightning,and Catalyst.
PyTorch provides two high-level features:

    1)Tensor computing (like NumPy) with strong acceleration via graphics processing units (GPU)
    2)Deep neural networks built on a tape-based automatic differentiation system

# %%
## why i am preferring pytorch over tensorflow?
-> tesla uses pytorch for computer vision for its autopilot....

# %%
##what is a tensors?
->you cant feed images,natural language to a neural network directly instead we convert them to tensors
->and then feed it to nn for calculation.
->the nn also output tensors.
->it is a data structure similar to numpy arrays but numpy is only for cpu.
->tensor can have as many dimension as you want.

# %%
##research and development
->current generation neural networks only accepts one kind of input like natural language, images,raw data 
->but research is moving to create a neural network that takes all input type at once....
->they are creating a human brain!!!!!!!

# %% [markdown]
# # pytorch workflow
# ![2.jpg](attachment:2.jpg)

# %%
import cv2
import numpy as np
img = cv2.imread("foo.png")
cv2.imshow('window',img)
